# %%
import numpy as np
import pandas as pd

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("prasoonkottarathil/polycystic-ovary-syndrome-pcos")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/polycystic-ovary-syndrome-pcos

# %%
file_path = f"{path}/PCOS_data_without_infertility.xlsx"

df = pd.read_excel(file_path , sheet_name="Full_new")

df.head()
# Out:
#    Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)   \
# 0       1                 1           0          28         44.6        152.0
# 1       2                 2           0          36         65.0        161.5
# 2       3                 3           1          33         68.8        165.0
# 3       4                 4           0          37         65.0        148.0
# 4       5                 5           0          25         52.0        161.0
#
#          BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  ...  \
# 0  19.300000           15                78                22  ...
# 1  24.921163           15                74                20  ...
# 2  25.270891           11                72                18  ...
# 3  29.674945           13                72                20  ...
# 4  20.060954           11                72                18  ...
#
#    Fast food (Y/N)  Reg.Exercise(Y/N)  BP _Systolic (mmHg)  \
# ...

# %%
df.isnull().sum()
# Out:
# Sl. No                      0
# Patient File No.            0
# PCOS (Y/N)                  0
#  Age (yrs)                  0
# Weight (Kg)                 0
# Height(Cm)                  0
# BMI                         0
# Blood Group                 0
# Pulse rate(bpm)             0
# RR (breaths/min)            0
# Hb(g/dl)                    0
# Cycle(R/I)                  0
# Cycle length(days)          0
# Marraige Status (Yrs)       1
# Pregnant(Y/N)               0
# No. of aborptions           0
#   I   beta-HCG(mIU/mL)      0
# II    beta-HCG(mIU/mL)      0
# FSH(mIU/mL)                 0
# LH(mIU/mL)                  0
# FSH/LH                      0
# Hip(inch)                   0
# Waist(inch)                 0
# Waist:Hip Ratio             0
# TSH (mIU/L)                 0
# AMH(ng/mL)                  0
# PRL(ng/mL)                  0
# Vit D3 (ng/mL)              0
# PRG(ng/mL)                  0
# RBS(mg/dl)                  0
# Weight gain(Y/N)            0
# ...

# %%
df=df.drop(columns=['Sl. No','Patient File No.','Weight (Kg)','Height(Cm) ','Blood Group','Pulse rate(bpm) ','RR (breaths/min)','Hb(g/dl)','Cycle(R/I)','Cycle length(days)','Marraige Status (Yrs)','Pregnant(Y/N)','No. of aborptions','  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)' ,'Hip(inch)','Waist(inch)','Waist:Hip Ratio','TSH (mIU/L)','PRL(ng/mL)','Vit D3 (ng/mL)','PRG(ng/mL)','BP _Systolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)','Avg. F size (L) (mm)', 'Avg. F size (R) (mm)','Endometrium (mm)','Unnamed: 44'])

# %%
df.head()
# Out:
#    PCOS (Y/N)   Age (yrs)        BMI  FSH(mIU/mL)  LH(mIU/mL)    FSH/LH  \
# 0           0          28  19.300000         7.95        3.68  2.160326
# 1           0          36  24.921163         6.73        1.09  6.174312
# 2           1          33  25.270891         5.54        0.88  6.295455
# 3           0          37  29.674945         8.06        2.36  3.415254
# 4           0          25  20.060954         3.98        0.90  4.422222
#
#   AMH(ng/mL)  RBS(mg/dl)  Weight gain(Y/N)  hair growth(Y/N)  \
# 0       2.07        92.0                 0                 0
# 1       1.53        92.0                 0                 0
# 2       6.63        84.0                 0                 0
# 3       1.22        76.0                 0                 0
# 4       2.26        84.0                 0                 0
#
#    Skin darkening (Y/N)  Hair loss(Y/N)  Pimples(Y/N)  Fast food (Y/N)  \
# 0                     0               0             0              1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   PCOS (Y/N)            541 non-null    int64
#  1    Age (yrs)            541 non-null    int64
#  2   BMI                   541 non-null    float64
#  3   FSH(mIU/mL)           541 non-null    float64
#  4   LH(mIU/mL)            541 non-null    float64
#  5   FSH/LH                541 non-null    float64
#  6   AMH(ng/mL)            541 non-null    object
#  7   RBS(mg/dl)            541 non-null    float64
#  8   Weight gain(Y/N)      541 non-null    int64
#  9   hair growth(Y/N)      541 non-null    int64
#  10  Skin darkening (Y/N)  541 non-null    int64
#  11  Hair loss(Y/N)        541 non-null    int64
#  12  Pimples(Y/N)          541 non-null    int64
#  13  Fast food (Y/N)       540 non-null    float64
#  14  Reg.Exercise(Y/N)     541 non-null    int64
# ...

# %%
df['AMH(ng/mL)'] = pd.to_numeric(df['AMH(ng/mL)'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   PCOS (Y/N)            541 non-null    int64
#  1    Age (yrs)            541 non-null    int64
#  2   BMI                   541 non-null    float64
#  3   FSH(mIU/mL)           541 non-null    float64
#  4   LH(mIU/mL)            541 non-null    float64
#  5   FSH/LH                541 non-null    float64
#  6   AMH(ng/mL)            540 non-null    float64
#  7   RBS(mg/dl)            541 non-null    float64
#  8   Weight gain(Y/N)      541 non-null    int64
#  9   hair growth(Y/N)      541 non-null    int64
#  10  Skin darkening (Y/N)  541 non-null    int64
#  11  Hair loss(Y/N)        541 non-null    int64
#  12  Pimples(Y/N)          541 non-null    int64
#  13  Fast food (Y/N)       540 non-null    float64
#  14  Reg.Exercise(Y/N)     541 non-null    int64
# ...

# %%
df['AMH(ng/mL)'].fillna(df['AMH(ng/mL)'].median(), inplace=True)
# Out:
# <ipython-input-36-875dad61df57>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['AMH(ng/mL)'].fillna(df['AMH(ng/mL)'].median(), inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   PCOS (Y/N)            541 non-null    int64
#  1    Age (yrs)            541 non-null    int64
#  2   BMI                   541 non-null    float64
#  3   FSH(mIU/mL)           541 non-null    float64
#  4   LH(mIU/mL)            541 non-null    float64
#  5   FSH/LH                541 non-null    float64
#  6   AMH(ng/mL)            541 non-null    float64
#  7   RBS(mg/dl)            541 non-null    float64
#  8   Weight gain(Y/N)      541 non-null    int64
#  9   hair growth(Y/N)      541 non-null    int64
#  10  Skin darkening (Y/N)  541 non-null    int64
#  11  Hair loss(Y/N)        541 non-null    int64
#  12  Pimples(Y/N)          541 non-null    int64
#  13  Fast food (Y/N)       540 non-null    float64
#  14  Reg.Exercise(Y/N)     541 non-null    int64
# ...

# %%
df['Fast food (Y/N)'].fillna(df['Fast food (Y/N)'].mode()[0] , inplace=True)
# Out:
# <ipython-input-41-1dbb2d9ed3d1>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Fast food (Y/N)'].fillna(df['Fast food (Y/N)'].mode()[0] , inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   PCOS (Y/N)            541 non-null    int64
#  1    Age (yrs)            541 non-null    int64
#  2   BMI                   541 non-null    float64
#  3   FSH(mIU/mL)           541 non-null    float64
#  4   LH(mIU/mL)            541 non-null    float64
#  5   FSH/LH                541 non-null    float64
#  6   AMH(ng/mL)            541 non-null    float64
#  7   RBS(mg/dl)            541 non-null    float64
#  8   Weight gain(Y/N)      541 non-null    int64
#  9   hair growth(Y/N)      541 non-null    int64
#  10  Skin darkening (Y/N)  541 non-null    int64
#  11  Hair loss(Y/N)        541 non-null    int64
#  12  Pimples(Y/N)          541 non-null    int64
#  13  Fast food (Y/N)       541 non-null    float64
#  14  Reg.Exercise(Y/N)     541 non-null    int64
# ...

# %%
target=df['PCOS (Y/N)']
df.drop(columns=['PCOS (Y/N)'],inplace=True)

# %%
from imblearn.over_sampling import BorderlineSMOTE
from collections import Counter
oversample = BorderlineSMOTE()
data, target = oversample.fit_resample(df, target)

# %%
data.shape
# Out:
# (728, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 728 entries, 0 to 727
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0    Age (yrs)            728 non-null    int64
#  1   BMI                   728 non-null    float64
#  2   FSH(mIU/mL)           728 non-null    float64
#  3   LH(mIU/mL)            728 non-null    float64
#  4   FSH/LH                728 non-null    float64
#  5   AMH(ng/mL)            728 non-null    float64
#  6   RBS(mg/dl)            728 non-null    float64
#  7   Weight gain(Y/N)      728 non-null    int64
#  8   hair growth(Y/N)      728 non-null    int64
#  9   Skin darkening (Y/N)  728 non-null    int64
#  10  Hair loss(Y/N)        728 non-null    int64
#  11  Pimples(Y/N)          728 non-null    int64
#  12  Fast food (Y/N)       728 non-null    float64
#  13  Reg.Exercise(Y/N)     728 non-null    int64
#  14  BP _Diastolic (mmHg)  728 non-null    int64
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(data, target, test_size=0.15, random_state=1, stratify = target)

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
xgb_clf = xgb.XGBClassifier(n_estimators=100, learning_rate=0.1, max_depth=5, random_state=42)

# Train the model
xgb_clf.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
y_pred = xgb_clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print(f"Model Accuracy: {accuracy:.2f}")
# Out:
# Model Accuracy: 0.85

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.show()

# %%
import pickle
with open('pcos_model.pkl', 'wb') as f:
    pickle.dump(rfc, f)

# %%
import pickle

with open('pcos_model.pkl', 'wb') as f:
    pickle.dump(xgb_clf, f)

print("XGBoost model saved successfully!")
# Out:
# XGBoost model saved successfully!
